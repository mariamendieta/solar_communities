# %%
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
from descartes import PolygonPatch
import fiona
from shapely.geometry import Polygon, MultiPolygon, shape
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9d07fd35d32a> in <module>()
#       2 from matplotlib.collections import PatchCollection
#       3 from descartes import PolygonPatch
# ----> 4 import fiona
#       5 from shapely.geometry import Polygon, MultiPolygon, shape
#       6 import geopandas
#
# /Users/mariamendieta/anaconda2/lib/python2.7/site-packages/fiona/__init__.py in <module>()
#      67 from six import string_types
#      68
# ---> 69 from fiona.collection import Collection, BytesCollection, vsi_path
#      70 from fiona._drivers import driver_count, GDALEnv
#      71 from fiona.drvsupport import supported_drivers
#
# /Users/mariamendieta/anaconda2/lib/python2.7/site-packages/fiona/collection.py in <module>()
#       5 import sys
#       6
# ----> 7 from fiona.ogrext import Iterator, ItemsIterator, KeysIterator
#       8 from fiona.ogrext import Session, WritingSession
#       9 from fiona.ogrext import (
#
# ImportError: dlopen(/Users/mariamendieta/anaconda2/lib/python2.7/site-packages/fiona/ogrext.so, 2): Library not loaded: @rpath/libnetcdf.11.dylib
#   Referenced from: /Users/mariamendieta/anaconda2/lib/libgdal.20.dylib
#   Reason: Incompatible library version: libgdal.20.dylib requires version 12.0.0 or later, but libnetcdf.11.dylib provides version 11.0.0

# %%
boros = geopandas.GeoDataFrame.from_file('input/NYShapefiles/ny_tracts10/tl_2010_36_tract10.shp')
boros.iloc[0]
# Out:
# /Users/mariamendieta/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# ALAND10                                                81287303
# AWATER10                                               16045715
# COUNTYFP10                                                  099
# FUNCSTAT10                                                    S
# GEOID10                                             36099951000
# INTPTLAT10                                          +42.5844045
# INTPTLON10                                         -076.6966089
# MTFCC10                                                   G5020
# NAME10                                                     9510
# NAMELSAD10                                    Census Tract 9510
# STATEFP10                                                    36
# TRACTCE10                                                951000
# geometry      POLYGON ((-76.72290699999999 42.546082, -76.72...
# Name: 0, dtype: object

# %%
cm = plt.get_cmap('RdBu')
num_colours = len(mp)
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
minx, miny, maxx, maxy = mp.bounds
w, h = maxx - minx, maxy - miny
ax.set_xlim(minx - 0.2 * w, maxx + 0.2 * w)
ax.set_ylim(miny - 0.2 * h, maxy + 0.2 * h)
ax.set_aspect(1)

patches = []
for idx, p in enumerate(mp):
    colour = cm(1. * idx / num_colours)
    patches.append(PolygonPatch(p, fc=colour, ec='#555555', alpha=1., zorder=1))
ax.add_collection(PatchCollection(patches, match_original=True))
ax.set_xticks([])
ax.set_yticks([])
plt.title("Shapefile polygons rendered using Shapely")
plt.show()
